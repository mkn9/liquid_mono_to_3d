# %% [raw]
# # OV-NeRF Synthetic Data Generator for Cone/Cylinder Classification
#
# This notebook demonstrates using Open-Vocabulary Neural Radiance Fields (OV-NeRF) to generate synthetic training data for cone and cylinder classification in the MONO_TO_3D tracking system.
#
# ## Key Features:
# - Semantic-aware 3D scene generation
# - Multi-view consistent rendering
# - Stereo camera setup integration
# - Ground truth annotation generation
